# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 

from scipy.signal import argrelextrema

sns.set()

metro_data = pd.read_csv('datasets/metro_norm_zhvi.csv').drop(columns = ['Unnamed: 0'])
metro_data = metro_data[metro_data['Date'] < '2015']

# %%
def my_min(city):
    city_df = metro_data[metro_data['MetroName'] == city]
    my_mins = city_df['Normalised_ZHVI'].to_numpy()
    
    '''
    plt.xticks(rotation = 'vertical')
    plt.plot(pd.to_datetime(city_df['Date']).dt.date, city_df['Normalised_ZHVI'])
    '''
my_min('Ames, IA')
