# %%
import pandas as pd
path_1 = 'datasets/cities_crosswalk.csv'
path_2 = 'datasets/City_time_series.csv'
path_3 = 'datasets/County_time_series.csv'
path_4 = 'datasets/CountyCrossWalk_Zillow.csv'
path_5 = 'datasets/DataDictionary.csv'
path_6 = 'datasets/Neighborhood_time_series.csv'
path_7 = 'datasets/State_time_series.csv'
path_8 = 'datasets/Zip_time_series.csv'
path_9 = 'datasets/Metro_time_series.csv'

# %%
country_cross_walk = pd.read_csv(path_4)

# %%
population_path = 'datasets/County_populations_census.csv'

# %%
import re

# %%
population_census_df = pd.read_csv(population_path, encoding = 'latin-1')

# %%
population_census_df
# Out:
#               GEO.id GEO.id2           GEO.display-label  \
# 0                 Id     Id2                   Geography
# 1     0500000US01001    1001     Autauga County, Alabama
# 2     0500000US01003    1003     Baldwin County, Alabama
# 3     0500000US01005    1005     Barbour County, Alabama
# 4     0500000US01007    1007        Bibb County, Alabama
# ...              ...     ...                         ...
# 3138  0500000US56037   56037  Sweetwater County, Wyoming
# 3139  0500000US56039   56039       Teton County, Wyoming
# 3140  0500000US56041   56041       Uinta County, Wyoming
# 3141  0500000US56043   56043    Washakie County, Wyoming
# 3142  0500000US56045   56045      Weston County, Wyoming
#
#                  rescen42010                    resbase42010  \
# 0     April 1, 2010 - Census  April 1, 2010 - Estimates Base
# 1                      54571                           54574
# 2                     182265                          182264
# 3                      27457                           27457
# 4                      22915                           22920
# ...                      ...                             ...
# 3138                   43806                           43806
# 3139                   21294                           21298
# 3140                   21118                           21121
# 3141                    8533                            8528
# 3142                    7208                            7208
#
#                                     respop72010  \
# 0     Population Estimate (as of July 1) - 2010
# 1                                         54754
# 2                                        183111
# 3                                         27330
# 4                                         22872
# ...                                         ...
# 3138                                      43574
# 3139                                      21297
# 3140                                      21089
# 3141                                       8530
# 3142                                       7199
#
#                                     respop72011  \
# 0     Population Estimate (as of July 1) - 2011
# 1                                         55208
# 2                                        186540
# 3                                         27350
# 4                                         22747
# ...                                         ...
# 3138                                      43981
# 3139                                      21414
# 3140                                      20893
# 3141                                       8448
# 3142                                       7142
#
#                                     respop72012  \
# 0     Population Estimate (as of July 1) - 2012
# 1                                         54936
# 2                                        190143
# 3                                         27174
# 4                                         22664
# ...                                         ...
# 3138                                      45005
# 3139                                      21625
# 3140                                      20994
# 3141                                       8408
# 3142                                       7077
#
#                                     respop72013  \
# 0     Population Estimate (as of July 1) - 2013
# 1                                         54713
# 2                                        194886
# 3                                         26944
# 4                                         22516
# ...                                         ...
# 3138                                      45162
# 3139                                      22318
# 3140                                      20953
# 3141                                       8414
# 3142                                       7137
#
#                                     respop72014  \
# 0     Population Estimate (as of July 1) - 2014
# 1                                         54876
# 2                                        199189
# 3                                         26758
# 4                                         22541
# ...                                         ...
# 3138                                      44957
# 3139                                      22777
# 3140                                      20827
# 3141                                       8275
# 3142                                       7138
#
#                                     respop72015  \
# 0     Population Estimate (as of July 1) - 2015
# 1                                         54838
# 2                                        202995
# 3                                         26294
# 4                                         22562
# ...                                         ...
# 3138                                      44754
# 3139                                      23016
# 3140                                      20770
# 3141                                       8280
# 3142                                       7197
#
#                                     respop72016  \
# 0     Population Estimate (as of July 1) - 2016
# 1                                         55242
# 2                                        207712
# 3                                         25819
# 4                                         22576
# ...                                         ...
# 3138                                      44275
# 3139                                      23161
# 3140                                      20691
# 3141                                       8168
# 3142                                       7213
#
#                                     respop72017  \
# 0     Population Estimate (as of July 1) - 2017
# 1                                         55443
# 2                                        212619
# 3                                         25158
# 4                                         22555
# ...                                         ...
# 3138                                      43547
# 3139                                      23261
# 3140                                      20456
# 3141                                       8035
# 3142                                       6986
#
#                                     respop72018
# 0     Population Estimate (as of July 1) - 2018
# 1                                         55601
# 2                                        218022
# 3                                         24881
# 4                                         22400
# ...                                         ...
# 3138                                      43051
# 3139                                      23081
# 3140                                      20299
# 3141                                       7885
# 3142                                       6967
#
# [3143 rows x 14 columns]

# %%
country_cross_walk
# Out:
#      CountyName       StateName  StateFIPS  CountyFIPS MetroName_Zillow  \
# 0          Pike    Pennsylvania         42         103     New York, NY
# 1         Bronx        New York         36           5     New York, NY
# 2         Essex      New Jersey         34          13     New York, NY
# 3         Kings        New York         36          47     New York, NY
# 4         Ocean      New Jersey         34          29     New York, NY
# ...         ...             ...        ...         ...              ...
# 3139      Allen          Kansas         20           1              NaN
# 3140      Anson  North Carolina         37           7              NaN
# 3141      Atoka        Oklahoma         40           5              NaN
# 3142      Avery  North Carolina         37          11              NaN
# 3143      Bacon         Georgia         13           5              NaN
#
#                                    CBSAName  CountyRegionID_Zillow  \
# 0     New York-Newark-Jersey City, NY-NJ-PA                    280
# 1     New York-Newark-Jersey City, NY-NJ-PA                    401
# 2     New York-Newark-Jersey City, NY-NJ-PA                    504
# 3     New York-Newark-Jersey City, NY-NJ-PA                    581
# 4     New York-Newark-Jersey City, NY-NJ-PA                    659
# ...                                     ...                    ...
# 3139                                    NaN                    368
# 3140                                    NaN                    374
# 3141                                    NaN                    375
# 3142                                    NaN                    376
# 3143                                    NaN                    377
#
#       MetroRegionID_Zillow   FIPS  CBSACode
# 0                 394913.0  42103   35620.0
# 1                 394913.0  36005   35620.0
# 2                 394913.0  34013   35620.0
# 3                 394913.0  36047   35620.0
# 4                 394913.0  34029   35620.0
# ...                    ...    ...       ...
# 3139                   NaN  20001       NaN
# 3140                   NaN  37007       NaN
# 3141                   NaN  40005       NaN
# 3142                   NaN  37011       NaN
# 3143                   NaN  13005       NaN
#
# [3144 rows x 10 columns]

# %%
population_census_df = population_census_df.drop('GEO.id', axis = 1)

# %%
population_census_df = population_census_df.drop('GEO.id2', axis = 1)

# %%
population_census_df
# Out:
#                GEO.display-label             rescen42010  \
# 0                      Geography  April 1, 2010 - Census
# 1        Autauga County, Alabama                   54571
# 2        Baldwin County, Alabama                  182265
# 3        Barbour County, Alabama                   27457
# 4           Bibb County, Alabama                   22915
# ...                          ...                     ...
# 3138  Sweetwater County, Wyoming                   43806
# 3139       Teton County, Wyoming                   21294
# 3140       Uinta County, Wyoming                   21118
# 3141    Washakie County, Wyoming                    8533
# 3142      Weston County, Wyoming                    7208
#
#                         resbase42010  \
# 0     April 1, 2010 - Estimates Base
# 1                              54574
# 2                             182264
# 3                              27457
# 4                              22920
# ...                              ...
# 3138                           43806
# 3139                           21298
# 3140                           21121
# 3141                            8528
# 3142                            7208
#
#                                     respop72010  \
# 0     Population Estimate (as of July 1) - 2010
# 1                                         54754
# 2                                        183111
# 3                                         27330
# 4                                         22872
# ...                                         ...
# 3138                                      43574
# 3139                                      21297
# 3140                                      21089
# 3141                                       8530
# 3142                                       7199
#
#                                     respop72011  \
# 0     Population Estimate (as of July 1) - 2011
# 1                                         55208
# 2                                        186540
# 3                                         27350
# 4                                         22747
# ...                                         ...
# 3138                                      43981
# 3139                                      21414
# 3140                                      20893
# 3141                                       8448
# 3142                                       7142
#
#                                     respop72012  \
# 0     Population Estimate (as of July 1) - 2012
# 1                                         54936
# 2                                        190143
# 3                                         27174
# 4                                         22664
# ...                                         ...
# 3138                                      45005
# 3139                                      21625
# 3140                                      20994
# 3141                                       8408
# 3142                                       7077
#
#                                     respop72013  \
# 0     Population Estimate (as of July 1) - 2013
# 1                                         54713
# 2                                        194886
# 3                                         26944
# 4                                         22516
# ...                                         ...
# 3138                                      45162
# 3139                                      22318
# 3140                                      20953
# 3141                                       8414
# 3142                                       7137
#
#                                     respop72014  \
# 0     Population Estimate (as of July 1) - 2014
# 1                                         54876
# 2                                        199189
# 3                                         26758
# 4                                         22541
# ...                                         ...
# 3138                                      44957
# 3139                                      22777
# 3140                                      20827
# 3141                                       8275
# 3142                                       7138
#
#                                     respop72015  \
# 0     Population Estimate (as of July 1) - 2015
# 1                                         54838
# 2                                        202995
# 3                                         26294
# 4                                         22562
# ...                                         ...
# 3138                                      44754
# 3139                                      23016
# 3140                                      20770
# 3141                                       8280
# 3142                                       7197
#
#                                     respop72016  \
# 0     Population Estimate (as of July 1) - 2016
# 1                                         55242
# 2                                        207712
# 3                                         25819
# 4                                         22576
# ...                                         ...
# 3138                                      44275
# 3139                                      23161
# 3140                                      20691
# 3141                                       8168
# 3142                                       7213
#
#                                     respop72017  \
# 0     Population Estimate (as of July 1) - 2017
# 1                                         55443
# 2                                        212619
# 3                                         25158
# 4                                         22555
# ...                                         ...
# 3138                                      43547
# 3139                                      23261
# 3140                                      20456
# 3141                                       8035
# 3142                                       6986
#
#                                     respop72018
# 0     Population Estimate (as of July 1) - 2018
# 1                                         55601
# 2                                        218022
# 3                                         24881
# 4                                         22400
# ...                                         ...
# 3138                                      43051
# 3139                                      23081
# 3140                                      20299
# 3141                                       7885
# 3142                                       6967
#
# [3143 rows x 12 columns]

# %%
new_header = population_census_df.iloc[0] #grab the first row for the header
population_census_df = population_census_df[1:] #take the data less the header row
population_census_df.columns = new_header

# %%
population_census_df
# Out:
# 0                      Geography April 1, 2010 - Census  \
# 1        Autauga County, Alabama                  54571
# 2        Baldwin County, Alabama                 182265
# 3        Barbour County, Alabama                  27457
# 4           Bibb County, Alabama                  22915
# 5         Blount County, Alabama                  57322
# ...                          ...                    ...
# 3138  Sweetwater County, Wyoming                  43806
# 3139       Teton County, Wyoming                  21294
# 3140       Uinta County, Wyoming                  21118
# 3141    Washakie County, Wyoming                   8533
# 3142      Weston County, Wyoming                   7208
#
# 0    April 1, 2010 - Estimates Base Population Estimate (as of July 1) - 2010  \
# 1                             54574                                     54754
# 2                            182264                                    183111
# 3                             27457                                     27330
# 4                             22920                                     22872
# 5                             57321                                     57373
# ...                             ...                                       ...
# 3138                          43806                                     43574
# 3139                          21298                                     21297
# 3140                          21121                                     21089
# 3141                           8528                                      8530
# 3142                           7208                                      7199
#
# 0    Population Estimate (as of July 1) - 2011  \
# 1                                        55208
# 2                                       186540
# 3                                        27350
# 4                                        22747
# 5                                        57554
# ...                                        ...
# 3138                                     43981
# 3139                                     21414
# 3140                                     20893
# 3141                                      8448
# 3142                                      7142
#
# 0    Population Estimate (as of July 1) - 2012  \
# 1                                        54936
# 2                                       190143
# 3                                        27174
# 4                                        22664
# 5                                        57570
# ...                                        ...
# 3138                                     45005
# 3139                                     21625
# 3140                                     20994
# 3141                                      8408
# 3142                                      7077
#
# 0    Population Estimate (as of July 1) - 2013  \
# 1                                        54713
# 2                                       194886
# 3                                        26944
# 4                                        22516
# 5                                        57611
# ...                                        ...
# 3138                                     45162
# 3139                                     22318
# 3140                                     20953
# 3141                                      8414
# 3142                                      7137
#
# 0    Population Estimate (as of July 1) - 2014  \
# 1                                        54876
# 2                                       199189
# 3                                        26758
# 4                                        22541
# 5                                        57521
# ...                                        ...
# 3138                                     44957
# 3139                                     22777
# 3140                                     20827
# 3141                                      8275
# 3142                                      7138
#
# 0    Population Estimate (as of July 1) - 2015  \
# 1                                        54838
# 2                                       202995
# 3                                        26294
# 4                                        22562
# 5                                        57522
# ...                                        ...
# 3138                                     44754
# 3139                                     23016
# 3140                                     20770
# 3141                                      8280
# 3142                                      7197
#
# 0    Population Estimate (as of July 1) - 2016  \
# 1                                        55242
# 2                                       207712
# 3                                        25819
# 4                                        22576
# 5                                        57517
# ...                                        ...
# 3138                                     44275
# 3139                                     23161
# 3140                                     20691
# 3141                                      8168
# 3142                                      7213
#
# 0    Population Estimate (as of July 1) - 2017  \
# 1                                        55443
# 2                                       212619
# 3                                        25158
# 4                                        22555
# 5                                        57827
# ...                                        ...
# 3138                                     43547
# 3139                                     23261
# 3140                                     20456
# 3141                                      8035
# 3142                                      6986
#
# 0    Population Estimate (as of July 1) - 2018
# 1                                        55601
# 2                                       218022
# 3                                        24881
# 4                                        22400
# 5                                        57840
# ...                                        ...
# 3138                                     43051
# 3139                                     23081
# 3140                                     20299
# 3141                                      7885
# 3142                                      6967
#
# [3142 rows x 12 columns]

# %%
population_census_df = population_census_df.rename(columns={'Geography': 'County'})

# %%
population_census_df
# Out:
# 0                         County April 1, 2010 - Census  \
# 1        Autauga County, Alabama                  54571
# 2        Baldwin County, Alabama                 182265
# 3        Barbour County, Alabama                  27457
# 4           Bibb County, Alabama                  22915
# 5         Blount County, Alabama                  57322
# ...                          ...                    ...
# 3138  Sweetwater County, Wyoming                  43806
# 3139       Teton County, Wyoming                  21294
# 3140       Uinta County, Wyoming                  21118
# 3141    Washakie County, Wyoming                   8533
# 3142      Weston County, Wyoming                   7208
#
# 0    April 1, 2010 - Estimates Base Population Estimate (as of July 1) - 2010  \
# 1                             54574                                     54754
# 2                            182264                                    183111
# 3                             27457                                     27330
# 4                             22920                                     22872
# 5                             57321                                     57373
# ...                             ...                                       ...
# 3138                          43806                                     43574
# 3139                          21298                                     21297
# 3140                          21121                                     21089
# 3141                           8528                                      8530
# 3142                           7208                                      7199
#
# 0    Population Estimate (as of July 1) - 2011  \
# 1                                        55208
# 2                                       186540
# 3                                        27350
# 4                                        22747
# 5                                        57554
# ...                                        ...
# 3138                                     43981
# 3139                                     21414
# 3140                                     20893
# 3141                                      8448
# 3142                                      7142
#
# 0    Population Estimate (as of July 1) - 2012  \
# 1                                        54936
# 2                                       190143
# 3                                        27174
# 4                                        22664
# 5                                        57570
# ...                                        ...
# 3138                                     45005
# 3139                                     21625
# 3140                                     20994
# 3141                                      8408
# 3142                                      7077
#
# 0    Population Estimate (as of July 1) - 2013  \
# 1                                        54713
# 2                                       194886
# 3                                        26944
# 4                                        22516
# 5                                        57611
# ...                                        ...
# 3138                                     45162
# 3139                                     22318
# 3140                                     20953
# 3141                                      8414
# 3142                                      7137
#
# 0    Population Estimate (as of July 1) - 2014  \
# 1                                        54876
# 2                                       199189
# 3                                        26758
# 4                                        22541
# 5                                        57521
# ...                                        ...
# 3138                                     44957
# 3139                                     22777
# 3140                                     20827
# 3141                                      8275
# 3142                                      7138
#
# 0    Population Estimate (as of July 1) - 2015  \
# 1                                        54838
# 2                                       202995
# 3                                        26294
# 4                                        22562
# 5                                        57522
# ...                                        ...
# 3138                                     44754
# 3139                                     23016
# 3140                                     20770
# 3141                                      8280
# 3142                                      7197
#
# 0    Population Estimate (as of July 1) - 2016  \
# 1                                        55242
# 2                                       207712
# 3                                        25819
# 4                                        22576
# 5                                        57517
# ...                                        ...
# 3138                                     44275
# 3139                                     23161
# 3140                                     20691
# 3141                                      8168
# 3142                                      7213
#
# 0    Population Estimate (as of July 1) - 2017  \
# 1                                        55443
# 2                                       212619
# 3                                        25158
# 4                                        22555
# 5                                        57827
# ...                                        ...
# 3138                                     43547
# 3139                                     23261
# 3140                                     20456
# 3141                                      8035
# 3142                                      6986
#
# 0    Population Estimate (as of July 1) - 2018
# 1                                        55601
# 2                                       218022
# 3                                        24881
# 4                                        22400
# 5                                        57840
# ...                                        ...
# 3138                                     43051
# 3139                                     23081
# 3140                                     20299
# 3141                                      7885
# 3142                                      6967
#
# [3142 rows x 12 columns]

# %%
population_census_df['County_temp'] = population_census_df['County'].str.replace('\sCounty,.*', '', regex=True)

# %%
population_census_df
# Out:
# 0                         County April 1, 2010 - Census  \
# 1        Autauga County, Alabama                  54571
# 2        Baldwin County, Alabama                 182265
# 3        Barbour County, Alabama                  27457
# 4           Bibb County, Alabama                  22915
# 5         Blount County, Alabama                  57322
# ...                          ...                    ...
# 3138  Sweetwater County, Wyoming                  43806
# 3139       Teton County, Wyoming                  21294
# 3140       Uinta County, Wyoming                  21118
# 3141    Washakie County, Wyoming                   8533
# 3142      Weston County, Wyoming                   7208
#
# 0    April 1, 2010 - Estimates Base Population Estimate (as of July 1) - 2010  \
# 1                             54574                                     54754
# 2                            182264                                    183111
# 3                             27457                                     27330
# 4                             22920                                     22872
# 5                             57321                                     57373
# ...                             ...                                       ...
# 3138                          43806                                     43574
# 3139                          21298                                     21297
# 3140                          21121                                     21089
# 3141                           8528                                      8530
# 3142                           7208                                      7199
#
# 0    Population Estimate (as of July 1) - 2011  \
# 1                                        55208
# 2                                       186540
# 3                                        27350
# 4                                        22747
# 5                                        57554
# ...                                        ...
# 3138                                     43981
# 3139                                     21414
# 3140                                     20893
# 3141                                      8448
# 3142                                      7142
#
# 0    Population Estimate (as of July 1) - 2012  \
# 1                                        54936
# 2                                       190143
# 3                                        27174
# 4                                        22664
# 5                                        57570
# ...                                        ...
# 3138                                     45005
# 3139                                     21625
# 3140                                     20994
# 3141                                      8408
# 3142                                      7077
#
# 0    Population Estimate (as of July 1) - 2013  \
# 1                                        54713
# 2                                       194886
# 3                                        26944
# 4                                        22516
# 5                                        57611
# ...                                        ...
# 3138                                     45162
# 3139                                     22318
# 3140                                     20953
# 3141                                      8414
# 3142                                      7137
#
# 0    Population Estimate (as of July 1) - 2014  \
# 1                                        54876
# 2                                       199189
# 3                                        26758
# 4                                        22541
# 5                                        57521
# ...                                        ...
# 3138                                     44957
# 3139                                     22777
# 3140                                     20827
# 3141                                      8275
# 3142                                      7138
#
# 0    Population Estimate (as of July 1) - 2015  \
# 1                                        54838
# 2                                       202995
# 3                                        26294
# 4                                        22562
# 5                                        57522
# ...                                        ...
# 3138                                     44754
# 3139                                     23016
# 3140                                     20770
# 3141                                      8280
# 3142                                      7197
#
# 0    Population Estimate (as of July 1) - 2016  \
# 1                                        55242
# 2                                       207712
# 3                                        25819
# 4                                        22576
# 5                                        57517
# ...                                        ...
# 3138                                     44275
# 3139                                     23161
# 3140                                     20691
# 3141                                      8168
# 3142                                      7213
#
# 0    Population Estimate (as of July 1) - 2017  \
# 1                                        55443
# 2                                       212619
# 3                                        25158
# 4                                        22555
# 5                                        57827
# ...                                        ...
# 3138                                     43547
# 3139                                     23261
# 3140                                     20456
# 3141                                      8035
# 3142                                      6986
#
# 0    Population Estimate (as of July 1) - 2018 County_temp
# 1                                        55601     Autauga
# 2                                       218022     Baldwin
# 3                                        24881     Barbour
# 4                                        22400        Bibb
# 5                                        57840      Blount
# ...                                        ...         ...
# 3138                                     43051  Sweetwater
# 3139                                     23081       Teton
# 3140                                     20299       Uinta
# 3141                                      7885    Washakie
# 3142                                      6967      Weston
#
# [3142 rows x 13 columns]

# %%
population_census_df['StateName'] = population_census_df['County'].str.replace('.*\,\s', '', regex=True)

# %%
population_census_df
# Out:
# 0                         County April 1, 2010 - Census  \
# 1        Autauga County, Alabama                  54571
# 2        Baldwin County, Alabama                 182265
# 3        Barbour County, Alabama                  27457
# 4           Bibb County, Alabama                  22915
# 5         Blount County, Alabama                  57322
# ...                          ...                    ...
# 3138  Sweetwater County, Wyoming                  43806
# 3139       Teton County, Wyoming                  21294
# 3140       Uinta County, Wyoming                  21118
# 3141    Washakie County, Wyoming                   8533
# 3142      Weston County, Wyoming                   7208
#
# 0    April 1, 2010 - Estimates Base Population Estimate (as of July 1) - 2010  \
# 1                             54574                                     54754
# 2                            182264                                    183111
# 3                             27457                                     27330
# 4                             22920                                     22872
# 5                             57321                                     57373
# ...                             ...                                       ...
# 3138                          43806                                     43574
# 3139                          21298                                     21297
# 3140                          21121                                     21089
# 3141                           8528                                      8530
# 3142                           7208                                      7199
#
# 0    Population Estimate (as of July 1) - 2011  \
# 1                                        55208
# 2                                       186540
# 3                                        27350
# 4                                        22747
# 5                                        57554
# ...                                        ...
# 3138                                     43981
# 3139                                     21414
# 3140                                     20893
# 3141                                      8448
# 3142                                      7142
#
# 0    Population Estimate (as of July 1) - 2012  \
# 1                                        54936
# 2                                       190143
# 3                                        27174
# 4                                        22664
# 5                                        57570
# ...                                        ...
# 3138                                     45005
# 3139                                     21625
# 3140                                     20994
# 3141                                      8408
# 3142                                      7077
#
# 0    Population Estimate (as of July 1) - 2013  \
# 1                                        54713
# 2                                       194886
# 3                                        26944
# 4                                        22516
# 5                                        57611
# ...                                        ...
# 3138                                     45162
# 3139                                     22318
# 3140                                     20953
# 3141                                      8414
# 3142                                      7137
#
# 0    Population Estimate (as of July 1) - 2014  \
# 1                                        54876
# 2                                       199189
# 3                                        26758
# 4                                        22541
# 5                                        57521
# ...                                        ...
# 3138                                     44957
# 3139                                     22777
# 3140                                     20827
# 3141                                      8275
# 3142                                      7138
#
# 0    Population Estimate (as of July 1) - 2015  \
# 1                                        54838
# 2                                       202995
# 3                                        26294
# 4                                        22562
# 5                                        57522
# ...                                        ...
# 3138                                     44754
# 3139                                     23016
# 3140                                     20770
# 3141                                      8280
# 3142                                      7197
#
# 0    Population Estimate (as of July 1) - 2016  \
# 1                                        55242
# 2                                       207712
# 3                                        25819
# 4                                        22576
# 5                                        57517
# ...                                        ...
# 3138                                     44275
# 3139                                     23161
# 3140                                     20691
# 3141                                      8168
# 3142                                      7213
#
# 0    Population Estimate (as of July 1) - 2017  \
# 1                                        55443
# 2                                       212619
# 3                                        25158
# 4                                        22555
# 5                                        57827
# ...                                        ...
# 3138                                     43547
# 3139                                     23261
# 3140                                     20456
# 3141                                      8035
# 3142                                      6986
#
# 0    Population Estimate (as of July 1) - 2018 County_temp StateName
# 1                                        55601     Autauga   Alabama
# 2                                       218022     Baldwin   Alabama
# 3                                        24881     Barbour   Alabama
# 4                                        22400        Bibb   Alabama
# 5                                        57840      Blount   Alabama
# ...                                        ...         ...       ...
# 3138                                     43051  Sweetwater   Wyoming
# 3139                                     23081       Teton   Wyoming
# 3140                                     20299       Uinta   Wyoming
# 3141                                      7885    Washakie   Wyoming
# 3142                                      6967      Weston   Wyoming
#
# [3142 rows x 14 columns]

# %%
population_census_df = population_census_df.rename(columns={'County': 'Full County'})

# %%
population_census_df = population_census_df.rename(columns={'County_temp': 'CountyName'})

# %%
metro_data = pd.read_csv('datasets/metro_data.csv')

# %%
metro_data
# Out:
#         Unnamed: 0        Date  RegionName  AgeOfInventory  \
# 0                0  1996-04-30       10180             NaN
# 1                1  1996-04-30       10220             NaN
# 2                2  1996-04-30       10300             NaN
# 3                3  1996-04-30       10420             NaN
# 4                4  1996-04-30       10500             NaN
# ...            ...         ...         ...             ...
# 210916      211176  2017-12-31       49660             NaN
# 210917      211177  2017-12-31       49700            60.0
# 210918      211178  2017-12-31       49740            64.0
# 210919      211179  2017-12-31       49780             NaN
# 210920      211180  2017-12-31       49820             NaN
#
#         DaysOnZillow_AllHomes  InventorySeasonallyAdjusted_AllHomes  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
# ...                       ...                                   ...
# 210916                    NaN                                2479.0
# 210917                    NaN                                 284.0
# 210918                    NaN                                 793.0
# 210919                    NaN                                 323.0
# 210920                    NaN                                   NaN
#
#         InventoryRaw_AllHomes  InventorySeasonallyAdjusted_BottomTier  \
# 0                         NaN                                     NaN
# 1                         NaN                                     NaN
# 2                         NaN                                     NaN
# 3                         NaN                                     NaN
# 4                         NaN                                     NaN
# ...                       ...                                     ...
# 210916                 2396.0                                   709.0
# 210917                  266.0                                     NaN
# 210918                  855.0                                   132.0
# 210919                  292.0                                   103.0
# 210920                    NaN                                     NaN
#
#         InventorySeasonallyAdjusted_MiddleTier  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 210916                                   659.0
# 210917                                     NaN
# 210918                                   236.0
# 210919                                    68.0
# 210920                                     NaN
#
#         InventorySeasonallyAdjusted_TopTier  ...  ZHVI_CondoCoop  \
# 0                                       NaN  ...             NaN
# 1                                       NaN  ...             NaN
# 2                                       NaN  ...             NaN
# 3                                       NaN  ...        109000.0
# 4                                       NaN  ...             NaN
# ...                                     ...  ...             ...
# 210916                               1111.0  ...        119400.0
# 210917                                115.0  ...             NaN
# 210918                                426.0  ...        114400.0
# 210919                                154.0  ...        126900.0
# 210920                                  NaN  ...             NaN
#
#         ZHVI_MiddleTier  ZHVI_SingleFamilyResidence  ZHVI_TopTier  \
# 0                   NaN                         NaN           NaN
# 1               28600.0                     28600.0           NaN
# 2               78500.0                     78600.0      124800.0
# 3               95700.0                     94400.0      169400.0
# 4               67600.0                     67500.0      112400.0
# ...                 ...                         ...           ...
# 210916          86900.0                     85900.0      162800.0
# 210917         272600.0                    274100.0      370000.0
# 210918         137500.0                    140700.0      229100.0
# 210919         114100.0                    113500.0      172000.0
# 210920          94900.0                     94900.0      167600.0
#
#         ZRI_AllHomes  ZRI_AllHomesPlusMultifamily  ZriPerSqft_AllHomes  \
# 0                NaN                          NaN                  NaN
# 1                NaN                          NaN                  NaN
# 2                NaN                          NaN                  NaN
# 3                NaN                          NaN                  NaN
# 4                NaN                          NaN                  NaN
# ...              ...                          ...                  ...
# 210916         848.0                        838.0                0.622
# 210917        1423.0                       1410.0                0.888
# 210918         904.0                        903.0                0.690
# 210919         937.0                        921.0                0.710
# 210920           NaN                          NaN                  NaN
#
#         Zri_MultiFamilyResidenceRental  Zri_SingleFamilyResidenceRental  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# ...                                ...                              ...
# 210916                           815.0                            840.0
# 210917                          1161.0                           1428.0
# 210918                           846.0                            912.0
# 210919                           843.0                            922.0
# 210920                             NaN                              NaN
#
#              MetroName
# 0          Abilene, TX
# 1              Ada, OK
# 2           Adrian, MI
# 3            Akron, OH
# 4           Albany, GA
# ...                ...
# 210916  Youngstown, OH
# 210917   Yuba City, CA
# 210918        Yuma, AZ
# 210919  Zanesville, OH
# 210920      Zapata, TX
#
# [210921 rows x 97 columns]

# %%
metro_data = metro_data[['RegionName', 'MetroName']]

# %%
metro_data
# Out:
#         RegionName       MetroName
# 0            10180     Abilene, TX
# 1            10220         Ada, OK
# 2            10300      Adrian, MI
# 3            10420       Akron, OH
# 4            10500      Albany, GA
# ...            ...             ...
# 210916       49660  Youngstown, OH
# 210917       49700   Yuba City, CA
# 210918       49740        Yuma, AZ
# 210919       49780  Zanesville, OH
# 210920       49820      Zapata, TX
#
# [210921 rows x 2 columns]

# %%
metro_data = metro_data.rename(columns={'RegionName': 'CBSACode'})

# %%
pd.set_option('display.max_columns', 500)

# %%
pop_vs_under_the_area = pd.merge(country_cross_walk, population_census_df, how='left')

# %%
pop_vs_under_the_area = pop_vs_under_the_area.dropna()

# %%
pop_vs_under_the_area['CBSACode'] = pop_vs_under_the_area['CBSACode'].astype('int')

# %%
pop_vs_under_the_area
# Out:
#      CountyName     StateName  StateFIPS  CountyFIPS MetroName_Zillow  \
# 0          Pike  Pennsylvania         42         103     New York, NY
# 1         Bronx      New York         36           5     New York, NY
# 2         Essex    New Jersey         34          13     New York, NY
# 3         Kings      New York         36          47     New York, NY
# 4         Ocean    New Jersey         34          29     New York, NY
# ...         ...           ...        ...         ...              ...
# 1798       Clay  South Dakota         46          27   Vermillion, SD
# 1799     Dawson         Texas         48         115       Lamesa, TX
# 1800     Moffat      Colorado          8          81        Craig, CO
# 1801     Reeves         Texas         48         389        Pecos, TX
# 1802  Wilbarger         Texas         48         487       Vernon, TX
#
#                                    CBSAName  CountyRegionID_Zillow  \
# 0     New York-Newark-Jersey City, NY-NJ-PA                    280
# 1     New York-Newark-Jersey City, NY-NJ-PA                    401
# 2     New York-Newark-Jersey City, NY-NJ-PA                    504
# 3     New York-Newark-Jersey City, NY-NJ-PA                    581
# 4     New York-Newark-Jersey City, NY-NJ-PA                    659
# ...                                     ...                    ...
# 1798                         Vermillion, SD                    130
# 1799                             Lamesa, TX                    982
# 1800                              Craig, CO                   1209
# 1801                              Pecos, TX                   1354
# 1802                             Vernon, TX                   2873
#
#       MetroRegionID_Zillow   FIPS  CBSACode                Full County  \
# 0                 394913.0  42103     35620  Pike County, Pennsylvania
# 1                 394913.0  36005     35620     Bronx County, New York
# 2                 394913.0  34013     35620   Essex County, New Jersey
# 3                 394913.0  36047     35620     Kings County, New York
# 4                 394913.0  34029     35620   Ocean County, New Jersey
# ...                    ...    ...       ...                        ...
# 1798              395186.0  46027     46820  Clay County, South Dakota
# 1799              394767.0  48115     29500       Dawson County, Texas
# 1800              753874.0   8081     18780    Moffat County, Colorado
# 1801              394968.0  48389     37780       Reeves County, Texas
# 1802              395188.0  48487     46900    Wilbarger County, Texas
#
#      April 1, 2010 - Census April 1, 2010 - Estimates Base  \
# 0                     57369                          57346
# 1                   1385108                        1384603
# 2                    783969                         783885
# 3                   2504700                        2504717
# 4                    576567                         576546
# ...                     ...                            ...
# 1798                  13864                          13868
# 1799                  13833                          13833
# 1800                  13795                          13791
# 1801                  13783                          13783
# 1802                  13535                          13535
#
#      Population Estimate (as of July 1) - 2010  \
# 0                                        57367
# 1                                      1387353
# 2                                       784062
# 3                                      2509877
# 4                                       577574
# ...                                        ...
# 1798                                     13828
# 1799                                     13827
# 1800                                     13794
# 1801                                     13836
# 1802                                     13511
#
#      Population Estimate (as of July 1) - 2011  \
# 0                                        57067
# 1                                      1397366
# 2                                       785531
# 3                                      2540822
# 4                                       578849
# ...                                        ...
# 1798                                     13980
# 1799                                     13746
# 1800                                     13421
# 1801                                     13812
# 1802                                     13454
#
#      Population Estimate (as of July 1) - 2012  \
# 0                                        56291
# 1                                      1411715
# 2                                       785137
# 3                                      2568876
# 4                                       579860
# ...                                        ...
# 1798                                     14063
# 1799                                     13613
# 1800                                     13169
# 1801                                     13987
# 1802                                     13293
#
#      Population Estimate (as of July 1) - 2013  \
# 0                                        56079
# 1                                      1422340
# 2                                       786817
# 3                                      2588501
# 4                                       582022
# ...                                        ...
# 1798                                     13893
# 1799                                     13219
# 1800                                     13124
# 1801                                     14218
# 1802                                     13207
#
#      Population Estimate (as of July 1) - 2014  \
# 0                                        55659
# 1                                      1431538
# 2                                       788975
# 3                                      2602680
# 4                                       584449
# ...                                        ...
# 1798                                     13881
# 1799                                     13448
# 1800                                     12934
# 1801                                     14557
# 1802                                     12991
#
#      Population Estimate (as of July 1) - 2015  \
# 0                                        55350
# 1                                      1440726
# 2                                       790508
# 3                                      2610607
# 4                                       587137
# ...                                        ...
# 1798                                     13764
# 1799                                     12990
# 1800                                     12938
# 1801                                     14955
# 1802                                     13067
#
#      Population Estimate (as of July 1) - 2016  \
# 0                                        55024
# 1                                      1445237
# 2                                       792617
# 3                                      2611232
# 4                                       590990
# ...                                        ...
# 1798                                     13917
# 1799                                     12998
# 1800                                     13143
# 1801                                     15122
# 1802                                     12904
#
#      Population Estimate (as of July 1) - 2017  \
# 0                                        55523
# 1                                      1439725
# 2                                       795908
# 3                                      2596385
# 4                                       595470
# ...                                        ...
# 1798                                     14021
# 1799                                     12766
# 1800                                     13095
# 1801                                     15295
# 1802                                     12747
#
#      Population Estimate (as of July 1) - 2018
# 0                                        55933
# 1                                      1432132
# 2                                       799767
# 3                                      2582830
# 4                                       601651
# ...                                        ...
# 1798                                     14041
# 1799                                     12619
# 1800                                     13188
# 1801                                     15695
# 1802                                     12820
#
# [1691 rows x 22 columns]

# %%
pop_vs_under_the_area = pd.merge(pop_vs_under_the_area, metro_data)

# %%
pop_vs_under_the_area
# Out:
#        CountyName     StateName  StateFIPS  CountyFIPS MetroName_Zillow  \
# 0            Pike  Pennsylvania         42         103     New York, NY
# 1            Pike  Pennsylvania         42         103     New York, NY
# 2            Pike  Pennsylvania         42         103     New York, NY
# 3            Pike  Pennsylvania         42         103     New York, NY
# 4            Pike  Pennsylvania         42         103     New York, NY
# ...           ...           ...        ...         ...              ...
# 403455  Wilbarger         Texas         48         487       Vernon, TX
# 403456  Wilbarger         Texas         48         487       Vernon, TX
# 403457  Wilbarger         Texas         48         487       Vernon, TX
# 403458  Wilbarger         Texas         48         487       Vernon, TX
# 403459  Wilbarger         Texas         48         487       Vernon, TX
#
#                                      CBSAName  CountyRegionID_Zillow  \
# 0       New York-Newark-Jersey City, NY-NJ-PA                    280
# 1       New York-Newark-Jersey City, NY-NJ-PA                    280
# 2       New York-Newark-Jersey City, NY-NJ-PA                    280
# 3       New York-Newark-Jersey City, NY-NJ-PA                    280
# 4       New York-Newark-Jersey City, NY-NJ-PA                    280
# ...                                       ...                    ...
# 403455                             Vernon, TX                   2873
# 403456                             Vernon, TX                   2873
# 403457                             Vernon, TX                   2873
# 403458                             Vernon, TX                   2873
# 403459                             Vernon, TX                   2873
#
#         MetroRegionID_Zillow   FIPS  CBSACode                Full County  \
# 0                   394913.0  42103     35620  Pike County, Pennsylvania
# 1                   394913.0  42103     35620  Pike County, Pennsylvania
# 2                   394913.0  42103     35620  Pike County, Pennsylvania
# 3                   394913.0  42103     35620  Pike County, Pennsylvania
# 4                   394913.0  42103     35620  Pike County, Pennsylvania
# ...                      ...    ...       ...                        ...
# 403455              395188.0  48487     46900    Wilbarger County, Texas
# 403456              395188.0  48487     46900    Wilbarger County, Texas
# 403457              395188.0  48487     46900    Wilbarger County, Texas
# 403458              395188.0  48487     46900    Wilbarger County, Texas
# 403459              395188.0  48487     46900    Wilbarger County, Texas
#
#        April 1, 2010 - Census April 1, 2010 - Estimates Base  \
# 0                       57369                          57346
# 1                       57369                          57346
# 2                       57369                          57346
# 3                       57369                          57346
# 4                       57369                          57346
# ...                       ...                            ...
# 403455                  13535                          13535
# 403456                  13535                          13535
# 403457                  13535                          13535
# 403458                  13535                          13535
# 403459                  13535                          13535
#
#        Population Estimate (as of July 1) - 2010  \
# 0                                          57367
# 1                                          57367
# 2                                          57367
# 3                                          57367
# 4                                          57367
# ...                                          ...
# 403455                                     13511
# 403456                                     13511
# 403457                                     13511
# 403458                                     13511
# 403459                                     13511
#
#        Population Estimate (as of July 1) - 2011  \
# 0                                          57067
# 1                                          57067
# 2                                          57067
# 3                                          57067
# 4                                          57067
# ...                                          ...
# 403455                                     13454
# 403456                                     13454
# 403457                                     13454
# 403458                                     13454
# 403459                                     13454
#
#        Population Estimate (as of July 1) - 2012  \
# 0                                          56291
# 1                                          56291
# 2                                          56291
# 3                                          56291
# 4                                          56291
# ...                                          ...
# 403455                                     13293
# 403456                                     13293
# 403457                                     13293
# 403458                                     13293
# 403459                                     13293
#
#        Population Estimate (as of July 1) - 2013  \
# 0                                          56079
# 1                                          56079
# 2                                          56079
# 3                                          56079
# 4                                          56079
# ...                                          ...
# 403455                                     13207
# 403456                                     13207
# 403457                                     13207
# 403458                                     13207
# 403459                                     13207
#
#        Population Estimate (as of July 1) - 2014  \
# 0                                          55659
# 1                                          55659
# 2                                          55659
# 3                                          55659
# 4                                          55659
# ...                                          ...
# 403455                                     12991
# 403456                                     12991
# 403457                                     12991
# 403458                                     12991
# 403459                                     12991
#
#        Population Estimate (as of July 1) - 2015  \
# 0                                          55350
# 1                                          55350
# 2                                          55350
# 3                                          55350
# 4                                          55350
# ...                                          ...
# 403455                                     13067
# 403456                                     13067
# 403457                                     13067
# 403458                                     13067
# 403459                                     13067
#
#        Population Estimate (as of July 1) - 2016  \
# 0                                          55024
# 1                                          55024
# 2                                          55024
# 3                                          55024
# 4                                          55024
# ...                                          ...
# 403455                                     12904
# 403456                                     12904
# 403457                                     12904
# 403458                                     12904
# 403459                                     12904
#
#        Population Estimate (as of July 1) - 2017  \
# 0                                          55523
# 1                                          55523
# 2                                          55523
# 3                                          55523
# 4                                          55523
# ...                                          ...
# 403455                                     12747
# 403456                                     12747
# 403457                                     12747
# 403458                                     12747
# 403459                                     12747
#
#        Population Estimate (as of July 1) - 2018     MetroName
# 0                                          55933  New York, NY
# 1                                          55933  New York, NY
# 2                                          55933  New York, NY
# 3                                          55933  New York, NY
# 4                                          55933  New York, NY
# ...                                          ...           ...
# 403455                                     12820    Vernon, TX
# 403456                                     12820    Vernon, TX
# 403457                                     12820    Vernon, TX
# 403458                                     12820    Vernon, TX
# 403459                                     12820    Vernon, TX
#
# [403460 rows x 23 columns]

# %%
column_list = ['MetroName_Zillow', 'CBSAName', 'MetroRegionID_Zillow', 'CBSACode', 'MetroName']

# %%
pop_vs_under_the_area
# Out:
#        CountyName     StateName  StateFIPS  CountyFIPS MetroName_Zillow  \
# 0            Pike  Pennsylvania         42         103     New York, NY
# 1            Pike  Pennsylvania         42         103     New York, NY
# 2            Pike  Pennsylvania         42         103     New York, NY
# 3            Pike  Pennsylvania         42         103     New York, NY
# 4            Pike  Pennsylvania         42         103     New York, NY
# ...           ...           ...        ...         ...              ...
# 403455  Wilbarger         Texas         48         487       Vernon, TX
# 403456  Wilbarger         Texas         48         487       Vernon, TX
# 403457  Wilbarger         Texas         48         487       Vernon, TX
# 403458  Wilbarger         Texas         48         487       Vernon, TX
# 403459  Wilbarger         Texas         48         487       Vernon, TX
#
#                                      CBSAName  CountyRegionID_Zillow  \
# 0       New York-Newark-Jersey City, NY-NJ-PA                    280
# 1       New York-Newark-Jersey City, NY-NJ-PA                    280
# 2       New York-Newark-Jersey City, NY-NJ-PA                    280
# 3       New York-Newark-Jersey City, NY-NJ-PA                    280
# 4       New York-Newark-Jersey City, NY-NJ-PA                    280
# ...                                       ...                    ...
# 403455                             Vernon, TX                   2873
# 403456                             Vernon, TX                   2873
# 403457                             Vernon, TX                   2873
# 403458                             Vernon, TX                   2873
# 403459                             Vernon, TX                   2873
#
#         MetroRegionID_Zillow   FIPS  CBSACode                Full County  \
# 0                   394913.0  42103     35620  Pike County, Pennsylvania
# 1                   394913.0  42103     35620  Pike County, Pennsylvania
# 2                   394913.0  42103     35620  Pike County, Pennsylvania
# 3                   394913.0  42103     35620  Pike County, Pennsylvania
# 4                   394913.0  42103     35620  Pike County, Pennsylvania
# ...                      ...    ...       ...                        ...
# 403455              395188.0  48487     46900    Wilbarger County, Texas
# 403456              395188.0  48487     46900    Wilbarger County, Texas
# 403457              395188.0  48487     46900    Wilbarger County, Texas
# 403458              395188.0  48487     46900    Wilbarger County, Texas
# 403459              395188.0  48487     46900    Wilbarger County, Texas
#
#        April 1, 2010 - Census April 1, 2010 - Estimates Base  \
# 0                       57369                          57346
# 1                       57369                          57346
# 2                       57369                          57346
# 3                       57369                          57346
# 4                       57369                          57346
# ...                       ...                            ...
# 403455                  13535                          13535
# 403456                  13535                          13535
# 403457                  13535                          13535
# 403458                  13535                          13535
# 403459                  13535                          13535
#
#        Population Estimate (as of July 1) - 2010  \
# 0                                          57367
# 1                                          57367
# 2                                          57367
# 3                                          57367
# 4                                          57367
# ...                                          ...
# 403455                                     13511
# 403456                                     13511
# 403457                                     13511
# 403458                                     13511
# 403459                                     13511
#
#        Population Estimate (as of July 1) - 2011  \
# 0                                          57067
# 1                                          57067
# 2                                          57067
# 3                                          57067
# 4                                          57067
# ...                                          ...
# 403455                                     13454
# 403456                                     13454
# 403457                                     13454
# 403458                                     13454
# 403459                                     13454
#
#        Population Estimate (as of July 1) - 2012  \
# 0                                          56291
# 1                                          56291
# 2                                          56291
# 3                                          56291
# 4                                          56291
# ...                                          ...
# 403455                                     13293
# 403456                                     13293
# 403457                                     13293
# 403458                                     13293
# 403459                                     13293
#
#        Population Estimate (as of July 1) - 2013  \
# 0                                          56079
# 1                                          56079
# 2                                          56079
# 3                                          56079
# 4                                          56079
# ...                                          ...
# 403455                                     13207
# 403456                                     13207
# 403457                                     13207
# 403458                                     13207
# 403459                                     13207
#
#        Population Estimate (as of July 1) - 2014  \
# 0                                          55659
# 1                                          55659
# 2                                          55659
# 3                                          55659
# 4                                          55659
# ...                                          ...
# 403455                                     12991
# 403456                                     12991
# 403457                                     12991
# 403458                                     12991
# 403459                                     12991
#
#        Population Estimate (as of July 1) - 2015  \
# 0                                          55350
# 1                                          55350
# 2                                          55350
# 3                                          55350
# 4                                          55350
# ...                                          ...
# 403455                                     13067
# 403456                                     13067
# 403457                                     13067
# 403458                                     13067
# 403459                                     13067
#
#        Population Estimate (as of July 1) - 2016  \
# 0                                          55024
# 1                                          55024
# 2                                          55024
# 3                                          55024
# 4                                          55024
# ...                                          ...
# 403455                                     12904
# 403456                                     12904
# 403457                                     12904
# 403458                                     12904
# 403459                                     12904
#
#        Population Estimate (as of July 1) - 2017  \
# 0                                          55523
# 1                                          55523
# 2                                          55523
# 3                                          55523
# 4                                          55523
# ...                                          ...
# 403455                                     12747
# 403456                                     12747
# 403457                                     12747
# 403458                                     12747
# 403459                                     12747
#
#        Population Estimate (as of July 1) - 2018     MetroName
# 0                                          55933  New York, NY
# 1                                          55933  New York, NY
# 2                                          55933  New York, NY
# 3                                          55933  New York, NY
# 4                                          55933  New York, NY
# ...                                          ...           ...
# 403455                                     12820    Vernon, TX
# 403456                                     12820    Vernon, TX
# 403457                                     12820    Vernon, TX
# 403458                                     12820    Vernon, TX
# 403459                                     12820    Vernon, TX
#
# [403460 rows x 23 columns]

# %%
pop_vs_under_the_area['April 1, 2010 - Census'] = pop_vs_under_the_area['April 1, 2010 - Census'].astype('int')

# %%
lalala = pop_vs_under_the_area.groupby(column_list).sum()

# %%
lalala.reset_index()
# Out:
#     MetroName_Zillow                           CBSAName  MetroRegionID_Zillow  \
# 0       Aberdeen, WA                       Aberdeen, WA              394298.0
# 1        Abilene, TX                        Abilene, TX              394299.0
# 2            Ada, OK                            Ada, OK              394300.0
# 3         Adrian, MI                         Adrian, MI              394302.0
# 4          Akron, OH                          Akron, OH              394304.0
# ..               ...                                ...                   ...
# 871   Youngstown, OH  Youngstown-Warren-Boardman, OH-PA              395245.0
# 872    Yuba City, CA                      Yuba City, CA              395246.0
# 873         Yuma, AZ                           Yuma, AZ              395247.0
# 874   Zanesville, OH                     Zanesville, OH              395248.0
# 875       Zapata, TX                         Zapata, TX              753929.0
#
#      CBSACode       MetroName  StateFIPS  CountyFIPS  CountyRegionID_Zillow  \
# 0       10140    Aberdeen, WA      13303        6777                 793913
# 1       10180     Abilene, TX      37584      196533                1087065
# 2       10220         Ada, OK      10440       32103                 648585
# 3       10300      Adrian, MI       6786       23751                 484416
# 4       10420       Akron, OH      20358       74646                 881919
# ..        ...             ...        ...         ...                    ...
# 871     49660  Youngstown, OH      31320       88479                1614285
# 872     49700   Yuba City, CA       3132       56376                 459621
# 873     49740        Yuma, AZ       1044        7047                  90567
# 874     49780  Zanesville, OH      10179       31059                 733932
# 875     49820      Zapata, TX      10320      108575                 323790
#
#          FIPS  April 1, 2010 - Census
# 0    13309777              18272047.0
# 1    37780533              43130772.0
# 2    10472103               9785412.0
# 3     6809751              26071812.0
# 4    20432646             183535200.0
# ..        ...                     ...
# 871  31408479             147666753.0
# 872   3188376              43558812.0
# 873   1051047              51091011.0
# 874  10210059              22465314.0
# 875  10428575               3013870.0
#
# [876 rows x 10 columns]

# %%
lalala = lalala.drop('CountyFIPS', axis = 1)

# %%
lalala = lalala.drop('StateFIPS', axis = 1)

# %%
lalala = lalala.drop('FIPS', axis = 1)

# %%
lalala = lalala.drop('CountyRegionID_Zillow', axis = 1)

# %%
pop_vs_under_the_area_final = lalala.reset_index()

# %%
pop_vs_under_the_area_final
# Out:
#     MetroName_Zillow                           CBSAName  MetroRegionID_Zillow  \
# 0       Aberdeen, WA                       Aberdeen, WA              394298.0
# 1        Abilene, TX                        Abilene, TX              394299.0
# 2            Ada, OK                            Ada, OK              394300.0
# 3         Adrian, MI                         Adrian, MI              394302.0
# 4          Akron, OH                          Akron, OH              394304.0
# ..               ...                                ...                   ...
# 871   Youngstown, OH  Youngstown-Warren-Boardman, OH-PA              395245.0
# 872    Yuba City, CA                      Yuba City, CA              395246.0
# 873         Yuma, AZ                           Yuma, AZ              395247.0
# 874   Zanesville, OH                     Zanesville, OH              395248.0
# 875       Zapata, TX                         Zapata, TX              753929.0
#
#      CBSACode       MetroName  April 1, 2010 - Census
# 0       10140    Aberdeen, WA              18272047.0
# 1       10180     Abilene, TX              43130772.0
# 2       10220         Ada, OK               9785412.0
# 3       10300      Adrian, MI              26071812.0
# 4       10420       Akron, OH             183535200.0
# ..        ...             ...                     ...
# 871     49660  Youngstown, OH             147666753.0
# 872     49700   Yuba City, CA              43558812.0
# 873     49740        Yuma, AZ              51091011.0
# 874     49780  Zanesville, OH              22465314.0
# 875     49820      Zapata, TX               3013870.0
#
# [876 rows x 6 columns]

# %%
AUB_path = 'datasets/AUB_results.csv'

# %%
AUB_df = pd.read_csv(AUB_path)

# %%
AUB_df = AUB_df.drop('Unnamed: 0', axis = 1)

# %%
AUB_df = AUB_df.rename(columns={'CBSA_Code': 'CBSACode'})

# %%
pop_vs_under_the_area_final['CBSACode'][0]
# Out:
# 10140

# %%
AUB_df.drop(AUB_df.tail(1).index,inplace=True)

# %%
AUB_df['CBSACode'] = AUB_df['CBSACode'].astype('int')

# %%
pop_vs_under_the_area_final = pd.merge(pop_vs_under_the_area_final, AUB_df)

# %%
pop_vs_under_the_area_final
# Out:
#     MetroName_Zillow                           CBSAName  MetroRegionID_Zillow  \
# 0       Aberdeen, WA                       Aberdeen, WA              394298.0
# 1            Ada, OK                            Ada, OK              394300.0
# 2         Adrian, MI                         Adrian, MI              394302.0
# 3          Akron, OH                          Akron, OH              394304.0
# 4         Albany, GA                         Albany, GA              394306.0
# ..               ...                                ...                   ...
# 632   Youngstown, OH  Youngstown-Warren-Boardman, OH-PA              395245.0
# 633    Yuba City, CA                      Yuba City, CA              395246.0
# 634         Yuma, AZ                           Yuma, AZ              395247.0
# 635   Zanesville, OH                     Zanesville, OH              395248.0
# 636       Zapata, TX                         Zapata, TX              753929.0
#
#      CBSACode       MetroName  April 1, 2010 - Census           AUC
# 0       10140    Aberdeen, WA              18272047.0  6.279530e+09
# 1       10220         Ada, OK               9785412.0  1.395506e+08
# 2       10300      Adrian, MI              26071812.0  1.540726e+10
# 3       10420       Akron, OH             183535200.0  6.091144e+09
# 4       10500      Albany, GA              41057388.0  5.610292e+09
# ..        ...             ...                     ...           ...
# 632     49660  Youngstown, OH             147666753.0  5.133751e+09
# 633     49700   Yuba City, CA              43558812.0  5.875918e+10
# 634     49740        Yuma, AZ              51091011.0  2.561689e+10
# 635     49780  Zanesville, OH              22465314.0  9.613770e+08
# 636     49820      Zapata, TX               3013870.0  2.413152e+07
#
# [637 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final['April 1, 2010 - Census'], y=pop_vs_under_the_area_final['AUC'])

# %%
AUB_norm_path = 'datasets/AUB_results_normalized.csv'

# %%
AUB_norm_df = pd.read_csv(AUB_norm_path)

# %%
AUB_norm_df = AUB_norm_df.drop('Unnamed: 0', axis = 1)

# %%
AUB_norm_df = AUB_norm_df.rename(columns={'CBSA_Code': 'CBSACode'})

# %%
AUB_norm_df
# Out:
#           CBSACode       AUC
# 0            10140 -0.369030
# 1            10220 -0.671346
# 2            10300  0.080395
# 3            10420 -0.378305
# 4            10500 -0.401981
# ..             ...       ...
# 658          49700  2.214927
# 659          49740  0.583090
# 660          49780 -0.630881
# 661          49820 -0.677029
# 662  United_States -0.140138
#
# [663 rows x 2 columns]

# %%
AUB_norm_df.drop(AUB_norm_df.tail(1).index,inplace=True)

# %%
AUB_norm_df['CBSACode'] = AUB_norm_df['CBSACode'].astype('int')

# %%
AUB_norm_df = AUB_norm_df.rename(columns={'AUC': 'AUC_normalized'})

# %%
pop_vs_under_the_area_final = pd.merge(pop_vs_under_the_area_final, AUB_norm_df)

# %%
pop_vs_under_the_area_final
# Out:
#     MetroName_Zillow                           CBSAName  MetroRegionID_Zillow  \
# 0       Aberdeen, WA                       Aberdeen, WA              394298.0
# 1            Ada, OK                            Ada, OK              394300.0
# 2         Adrian, MI                         Adrian, MI              394302.0
# 3          Akron, OH                          Akron, OH              394304.0
# 4         Albany, GA                         Albany, GA              394306.0
# ..               ...                                ...                   ...
# 632   Youngstown, OH  Youngstown-Warren-Boardman, OH-PA              395245.0
# 633    Yuba City, CA                      Yuba City, CA              395246.0
# 634         Yuma, AZ                           Yuma, AZ              395247.0
# 635   Zanesville, OH                     Zanesville, OH              395248.0
# 636       Zapata, TX                         Zapata, TX              753929.0
#
#      CBSACode       MetroName  April 1, 2010 - Census           AUC  \
# 0       10140    Aberdeen, WA              18272047.0  6.279530e+09
# 1       10220         Ada, OK               9785412.0  1.395506e+08
# 2       10300      Adrian, MI              26071812.0  1.540726e+10
# 3       10420       Akron, OH             183535200.0  6.091144e+09
# 4       10500      Albany, GA              41057388.0  5.610292e+09
# ..        ...             ...                     ...           ...
# 632     49660  Youngstown, OH             147666753.0  5.133751e+09
# 633     49700   Yuba City, CA              43558812.0  5.875918e+10
# 634     49740        Yuma, AZ              51091011.0  2.561689e+10
# 635     49780  Zanesville, OH              22465314.0  9.613770e+08
# 636     49820      Zapata, TX               3013870.0  2.413152e+07
#
#      AUC_normalized
# 0         -0.369030
# 1         -0.671346
# 2          0.080395
# 3         -0.378305
# 4         -0.401981
# ..              ...
# 632       -0.425445
# 633        2.214927
# 634        0.583090
# 635       -0.630881
# 636       -0.677029
#
# [637 rows x 8 columns]

# %%
arima_path = 'datasets/ARIMA_output.csv'

# %%
arima_df = pd.read_csv(arima_path)

# %%
arima_df
# Out:
#        Unnamed: 0  Metro Area        CI Area  Normalised CI
# 0           54215       20780  314740.497894       6.093877
# 1           39704       20780  314740.497894       6.093877
# 2           46229       20780  314740.497894       6.093877
# 3           44051       20780  314740.497894       6.093877
# 4             860       20780  314740.497894       6.093877
# ...           ...         ...            ...            ...
# 54773       51965       17260    8867.284447      -1.117270
# 54774       36029       17260    8867.284447      -1.117270
# 54775       42529       17260    8867.284447      -1.117270
# 54776       66485       17260    8867.284447      -1.117270
# 54777       13816       17260    8867.284447      -1.117270
#
# [54778 rows x 4 columns]

# %%
arima_df = arima_df.drop('Unnamed: 0', axis = 1)

# %%
arima_df = arima_df.rename(columns={'Metro Area': 'CBSACode'})

# %%
arima_df
# Out:
#        CBSACode        CI Area  Normalised CI
# 0         20780  314740.497894       6.093877
# 1         20780  314740.497894       6.093877
# 2         20780  314740.497894       6.093877
# 3         20780  314740.497894       6.093877
# 4         20780  314740.497894       6.093877
# ...         ...            ...            ...
# 54773     17260    8867.284447      -1.117270
# 54774     17260    8867.284447      -1.117270
# 54775     17260    8867.284447      -1.117270
# 54776     17260    8867.284447      -1.117270
# 54777     17260    8867.284447      -1.117270
#
# [54778 rows x 3 columns]

# %%
arima_df = arima_df.drop_duplicates()

# %%
pop_vs_under_the_area_final_arima = pd.merge(pop_vs_under_the_area_final, arima_df)

# %%
pop_vs_under_the_area_final_arima
# Out:
#     MetroName_Zillow                     CBSAName  MetroRegionID_Zillow  \
# 0       Aberdeen, WA                 Aberdeen, WA              394298.0
# 1            Ada, OK                      Ada, OK              394300.0
# 2         Albany, GA                   Albany, GA              394306.0
# 3         Albany, NY  Albany-Schenectady-Troy, NY              394308.0
# 4         Albany, OR                   Albany, OR              394307.0
# ..               ...                          ...                   ...
# 449      Yankton, SD                  Yankton, SD              395241.0
# 450         York, PA             York-Hanover, PA              395244.0
# 451         Yuma, AZ                     Yuma, AZ              395247.0
# 452   Zanesville, OH               Zanesville, OH              395248.0
# 453       Zapata, TX                   Zapata, TX              753929.0
#
#      CBSACode       MetroName  April 1, 2010 - Census           AUC  \
# 0       10140    Aberdeen, WA              18272047.0  6.279530e+09
# 1       10220         Ada, OK               9785412.0  1.395506e+08
# 2       10500      Albany, GA              41057388.0  5.610292e+09
# 3       10580      Albany, NY             227256876.0  2.745191e+09
# 4       10540      Albany, OR              30451392.0  5.806048e+09
# ..        ...             ...                     ...           ...
# 449     49460     Yankton, SD               5856318.0  4.736557e+09
# 450     49620        York, PA             113527692.0  1.040908e+10
# 451     49740        Yuma, AZ              51091011.0  2.561689e+10
# 452     49780  Zanesville, OH              22465314.0  9.613770e+08
# 453     49820      Zapata, TX               3013870.0  2.413152e+07
#
#      AUC_normalized       CI Area  Normalised CI
# 0         -0.369030  70946.320439       0.346281
# 1         -0.671346  37712.919546      -0.437217
# 2         -0.401981  28158.316132      -0.662472
# 3         -0.543051  32576.477673      -0.558311
# 4         -0.392343  97101.018193       0.962894
# ..              ...           ...            ...
# 449       -0.445002  85728.966209       0.694791
# 450       -0.165702  42912.564712      -0.314632
# 451        0.583090  81493.154941       0.594929
# 452       -0.630881  37616.458866      -0.439491
# 453       -0.677029  19246.807071      -0.872566
#
# [454 rows x 10 columns]

# %%
import scipy.stats as sy

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final_arima['April 1, 2010 - Census'], y=pop_vs_under_the_area_final_arima['AUC'])
ax.set(xlabel="Population (April 1, 2010)", ylabel="AUB")
ax.set_title("AUB Algorithm Output vs. Population")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final_arima['AUC'], pop_vs_under_the_area_final_arima['April 1, 2010 - Census'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = 0.02309733137707939

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final_arima['April 1, 2010 - Census'], y=pop_vs_under_the_area_final_arima['AUC_normalized'])
ax.set(xlabel="Population (April 1, 2010)", ylabel="AUB")
ax.set_title("AUB Algorithm Output vs. Population")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final_arima['AUC_normalized'], pop_vs_under_the_area_final_arima['April 1, 2010 - Census'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = 0.023097331377079398

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final_arima['April 1, 2010 - Census'], y=pop_vs_under_the_area_final_arima['Normalised CI'])
ax.set(xlabel="Population (April 1, 2010)", ylabel="ARIMA Normalized CI")
ax.set_title("ARIMA Algorithm Output vs. Population")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final_arima['Normalised CI'], pop_vs_under_the_area_final_arima['April 1, 2010 - Census'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = 0.01819678210789867

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final_arima['AUC_normalized'], y=pop_vs_under_the_area_final_arima['April 1, 2010 - Census'])
ax.set(xlabel="AUB (Normalized)", ylabel="Population (April 1, 2010)")
ax.set_title("Population vs. AUB Algorithm Output")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final_arima['AUC_normalized'], pop_vs_under_the_area_final_arima['April 1, 2010 - Census'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = 0.023097331377079398

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final_arima['Normalised CI'], y=pop_vs_under_the_area_final_arima['April 1, 2010 - Census'], )
ax.set(xlabel="ARIMA Normalized CI", ylabel="Population (April 1, 2010)")
ax.set_title("Population vs. ARIMA Algorithm Output")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final_arima['Normalised CI'], pop_vs_under_the_area_final_arima['April 1, 2010 - Census'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = 0.01819678210789867

# %%
#2020 Winter Quarter

# %%
import numpy as np

# %%
pop_vs_under_the_area_final
# Out:
#     MetroName_Zillow                           CBSAName  MetroRegionID_Zillow  \
# 0       Aberdeen, WA                       Aberdeen, WA              394298.0
# 1            Ada, OK                            Ada, OK              394300.0
# 2         Adrian, MI                         Adrian, MI              394302.0
# 3          Akron, OH                          Akron, OH              394304.0
# 4         Albany, GA                         Albany, GA              394306.0
# ..               ...                                ...                   ...
# 632   Youngstown, OH  Youngstown-Warren-Boardman, OH-PA              395245.0
# 633    Yuba City, CA                      Yuba City, CA              395246.0
# 634         Yuma, AZ                           Yuma, AZ              395247.0
# 635   Zanesville, OH                     Zanesville, OH              395248.0
# 636       Zapata, TX                         Zapata, TX              753929.0
#
#      CBSACode       MetroName  April 1, 2010 - Census           AUC  \
# 0       10140    Aberdeen, WA              18272047.0  6.279530e+09
# 1       10220         Ada, OK               9785412.0  1.395506e+08
# 2       10300      Adrian, MI              26071812.0  1.540726e+10
# 3       10420       Akron, OH             183535200.0  6.091144e+09
# 4       10500      Albany, GA              41057388.0  5.610292e+09
# ..        ...             ...                     ...           ...
# 632     49660  Youngstown, OH             147666753.0  5.133751e+09
# 633     49700   Yuba City, CA              43558812.0  5.875918e+10
# 634     49740        Yuma, AZ              51091011.0  2.561689e+10
# 635     49780  Zanesville, OH              22465314.0  9.613770e+08
# 636     49820      Zapata, TX               3013870.0  2.413152e+07
#
#      AUC_normalized
# 0         -0.369030
# 1         -0.671346
# 2          0.080395
# 3         -0.378305
# 4         -0.401981
# ..              ...
# 632       -0.425445
# 633        2.214927
# 634        0.583090
# 635       -0.630881
# 636       -0.677029
#
# [637 rows x 8 columns]

# %%
pop_vs_under_the_area_final['April 1, 2010 - Census Log'] = np.log(pop_vs_under_the_area_final['April 1, 2010 - Census'])
pop_vs_under_the_area_final['AUC Log'] = np.log(pop_vs_under_the_area_final['AUC'])
pop_vs_under_the_area_final['AUC_normalized Log'] = np.log(pop_vs_under_the_area_final['AUC_normalized'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
pop_vs_under_the_area_final
# Out:
#     MetroName_Zillow                           CBSAName  MetroRegionID_Zillow  \
# 0       Aberdeen, WA                       Aberdeen, WA              394298.0
# 1            Ada, OK                            Ada, OK              394300.0
# 2         Adrian, MI                         Adrian, MI              394302.0
# 3          Akron, OH                          Akron, OH              394304.0
# 4         Albany, GA                         Albany, GA              394306.0
# ..               ...                                ...                   ...
# 632   Youngstown, OH  Youngstown-Warren-Boardman, OH-PA              395245.0
# 633    Yuba City, CA                      Yuba City, CA              395246.0
# 634         Yuma, AZ                           Yuma, AZ              395247.0
# 635   Zanesville, OH                     Zanesville, OH              395248.0
# 636       Zapata, TX                         Zapata, TX              753929.0
#
#      CBSACode       MetroName  April 1, 2010 - Census           AUC  \
# 0       10140    Aberdeen, WA              18272047.0  6.279530e+09
# 1       10220         Ada, OK               9785412.0  1.395506e+08
# 2       10300      Adrian, MI              26071812.0  1.540726e+10
# 3       10420       Akron, OH             183535200.0  6.091144e+09
# 4       10500      Albany, GA              41057388.0  5.610292e+09
# ..        ...             ...                     ...           ...
# 632     49660  Youngstown, OH             147666753.0  5.133751e+09
# 633     49700   Yuba City, CA              43558812.0  5.875918e+10
# 634     49740        Yuma, AZ              51091011.0  2.561689e+10
# 635     49780  Zanesville, OH              22465314.0  9.613770e+08
# 636     49820      Zapata, TX               3013870.0  2.413152e+07
#
#      AUC_normalized  April 1, 2010 - Census Log    AUC Log  AUC_normalized Log
# 0         -0.369030                   16.720883  22.560561                 NaN
# 1         -0.671346                   16.096403  18.753938                 NaN
# 2          0.080395                   17.076365  23.458105           -2.520802
# 3         -0.378305                   19.027917  22.530102                 NaN
# 4         -0.401981                   17.530481  22.447869                 NaN
# ..              ...                         ...        ...                 ...
# 632       -0.425445                   18.810469  22.359103                 NaN
# 633        2.214927                   17.589623  24.796713            0.795220
# 634        0.583090                   17.749119  23.966518           -0.539414
# 635       -0.630881                   16.927483  20.683877                 NaN
# 636       -0.677029                   14.918736  16.999029                 NaN
#
# [637 rows x 11 columns]

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final['AUC'], y=pop_vs_under_the_area_final['April 1, 2010 - Census'])
ax.set(xlabel="AUB", ylabel="Population (April 1, 2010)")
ax.set_title("Population vs. AUB Algorithm Output")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final['AUC'], pop_vs_under_the_area_final['April 1, 2010 - Census'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = 0.16798558915998793

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final['AUC_normalized Log'], y=pop_vs_under_the_area_final['April 1, 2010 - Census Log'])
ax.set(xlabel="AUB", ylabel="Population (April 1, 2010) Log")
ax.set_title("Population Log vs. AUB Algorithm Output")
slope, intercept, r_value, p_value, std_err = sy.linregress(np.log(pop_vs_under_the_area_final['AUC_normalized Log']), pop_vs_under_the_area_final['April 1, 2010 - Census Log'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = nan

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final['AUC Log'], y=pop_vs_under_the_area_final['April 1, 2010 - Census'])
ax.set(xlabel="AUB Log", ylabel="Population (April 1, 2010)")
ax.set_title("Population vs. AUB Algorithm Output Log")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final['AUC Log'], pop_vs_under_the_area_final['April 1, 2010 - Census'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = nan

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final['AUC Log'], y=pop_vs_under_the_area_final['April 1, 2010 - Census Log'])
ax.set(xlabel="AUB Log", ylabel="Population (April 1, 2010) Log")
ax.set_title("Population Log vs. AUB Algorithm Output Log")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final['AUC Log'], pop_vs_under_the_area_final['April 1, 2010 - Census Log'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = nan

# %%
pop_vs_under_the_area_final_arima

# %%
pop_vs_under_the_area_final_arima['April 1, 2010 - Census Log'] = np.log(pop_vs_under_the_area_final_arima['April 1, 2010 - Census'])
pop_vs_under_the_area_final_arima['CI Area Log'] = np.log(pop_vs_under_the_area_final_arima['CI Area'])
pop_vs_under_the_area_final_arima['Normalised CI Log'] = np.log(pop_vs_under_the_area_final_arima['Normalised CI'])

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final_arima['CI Area'], y=pop_vs_under_the_area_final_arima['April 1, 2010 - Census'], )
ax.set(xlabel="ARIMA CI", ylabel="Population (April 1, 2010)")
ax.set_title("Population vs. ARIMA Algorithm Output")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final_arima['CI Area'], pop_vs_under_the_area_final_arima['April 1, 2010 - Census'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = 0.01819678210789872

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final_arima['CI Area'], y=pop_vs_under_the_area_final_arima['April 1, 2010 - Census Log'], )
ax.set(xlabel="ARIMA CI", ylabel="Population (April 1, 2010) Log")
ax.set_title("Population Log vs. ARIMA Algorithm Output")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final_arima['CI Area'], pop_vs_under_the_area_final_arima['April 1, 2010 - Census Log'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = -0.04170859932997702

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final_arima['CI Area Log'], y=pop_vs_under_the_area_final_arima['April 1, 2010 - Census'], )
ax.set(xlabel="ARIMA CI Log", ylabel="Population (April 1, 2010)")
ax.set_title("Population vs. ARIMA Algorithm Output Log")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final_arima['CI Area Log'], pop_vs_under_the_area_final_arima['April 1, 2010 - Census'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = 0.004060882479313393

# %%
ax = sns.regplot(x=pop_vs_under_the_area_final_arima['CI Area Log'], y=pop_vs_under_the_area_final_arima['April 1, 2010 - Census Log'], )
ax.set(xlabel="ARIMA CI Log", ylabel="Population (April 1, 2010) Log")
ax.set_title("Population Log vs. ARIMA Algorithm Output Log")
slope, intercept, r_value, p_value, std_err = sy.linregress(pop_vs_under_the_area_final_arima['CI Area Log'], pop_vs_under_the_area_final_arima['April 1, 2010 - Census Log'])
print("r = " + str(r_value))
plt.show()
# Out:
# r = -0.07079630797923282
